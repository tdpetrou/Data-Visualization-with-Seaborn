# %% [markdown]
# # Course Data
#
# This notebook contains notes on all of the course data

# %% [markdown]
# ## Airbnb Listings from Washington D.C

# %%
import pandas as pd
airbnb = pd.read_csv('../data/airbnb.csv')
airbnb.head()
# Out:
#      id        neighborhood        room_type  accommodates  bedrooms  price  \
# 0  3686  Historic Anacostia     Private room             1       1.0     55
# 1  3943            Edgewood     Private room             2       1.0     71
# 2  4529    Eastland Gardens     Private room             4       1.0     54
# 3  4967            Edgewood     Private room             1       1.0     99
# 4  5589    Kalorama Heights  Entire home/apt             3       1.0     99
#
#    security_deposit  cleaning_fee  rating  superhost       response_time  \
# 0                25            25    4.60          0  a few days or more
# 1                50             0    4.81          0                 NaN
# 2                25            50    4.66          0  within a few hours
# 3                50             0    4.74          1      within an hour
# 4                50             0    4.54          0  within a few hours
#
# ...

# %%
airbnb.shape
# Out:
# (7805, 19)

# %% [markdown]
# ## Covid
#
# * There are two groups of data - "usa" and "world"

# %%
covid = pd.read_csv('../data/covid.csv', parse_dates=['date'])
covid
# Out:
#         group       date                area  Daily Deaths  Daily Cases  \
# 0         usa 2020-01-22             Alabama             0            0
# 1         usa 2020-01-22              Alaska             0            0
# 2         usa 2020-01-22      American Samoa             0            0
# 3         usa 2020-01-22             Arizona             0            0
# 4         usa 2020-01-22            Arkansas             0            0
# ...       ...        ...                 ...           ...          ...
# 170851  world 2021-11-29             Vietnam           173        13770
# 170852  world 2021-11-29  West Bank and Gaza             7          574
# 170853  world 2021-11-29               Yemen             3            8
# 170854  world 2021-11-29              Zambia             0            7
# 170855  world 2021-11-29            Zimbabwe             1          275
#
#         Deaths    Cases
# 0            0        0
# 1            0        0
# 2            0        0
# ...

# %%
covid.shape
# Out:
# (170856, 7)

# %% [markdown]
# ## Diamonds
#
# Prices and attributes of diamonds

# %%
diamonds = pd.read_csv('../data/diamonds.csv')
diamonds.head()
# Out:
#    carat  price     shape clarity color        cut  depth fluorescence  \
# 0   0.23    250  Princess     VS1     H       Good   74.0         None
# 1   0.23    250  Princess     VS1     H       Good   77.8         None
# 2   0.32    253  Princess     SI2     I  Very Good   74.7         None
# 3   0.30    271  Princess     VS1     I  Very Good   74.0         None
# 4   0.30    272  Princess     SI1     I  Very Good   72.4        Faint
#
#    lxwRatio     polish   symmetry  table
# 0      1.01  Very Good       Good   81.0
# 1      1.00  Very Good       Good   71.0
# 2      1.04  Excellent  Very Good   72.0
# 3      1.03  Excellent       Good   74.0
# 4      1.01  Excellent  Very Good   68.0

# %%
diamonds.shape
# Out:
# (208380, 12)

# %% [markdown]
# ## City of Houston Employees

# %%
emp = pd.read_csv('../data/employee.csv', parse_dates=['hire_date'])
emp.head()
# Out:
#                    dept                       title  hire_date    salary  \
# 0                Police             POLICE SERGEANT 2001-12-03  87545.38
# 1                 Other  ASSISTANT CITY ATTORNEY II 2010-11-15  82182.00
# 2  Houston Public Works     SENIOR SLUDGE PROCESSOR 2006-01-09  49275.00
# 3                Police       SENIOR POLICE OFFICER 1997-05-27  75942.10
# 4                Police       SENIOR POLICE OFFICER 2006-01-23  69355.26
#
#     sex      race
# 0  Male     White
# 1  Male  Hispanic
# 2  Male     Black
# 3  Male  Hispanic
# 4  Male     White

# %%
emp.shape
# Out:
# (24308, 6)

# %% [markdown]
# ## Fraud detection

# %%
fraud = pd.read_csv('../data/fraud.csv', parse_dates=['signup_time', 'purchase_time'])
fraud.head()
# Out:
#    user_id         signup_time       purchase_time  purchase_value  \
# 0   285108 2015-07-15 04:36:55 2015-09-10 14:17:56              31
# 1   131009 2015-01-24 12:29:58 2015-04-13 04:53:55              31
# 2   328855 2015-03-11 00:54:12 2015-04-05 12:23:49              16
# 3   229053 2015-01-07 13:19:17 2015-01-09 10:12:06              29
# 4   108439 2015-02-08 21:11:04 2015-04-09 14:26:10              26
#
#        device_id  source  browser sex  age    ip_address  class
# 0  HZAKVUFTDOSFD  Direct   Chrome   M   49  2.818400e+09      0
# 1  XGQAJSOUJIZCC     SEO       IE   F   21  3.251268e+09      0
# 2  VCCTAYDCWKZIY  Direct       IE   M   26  2.727760e+09      0
# 3  MFFIHYNXCJLEY     SEO   Chrome   M   34  2.083420e+09      0
# 4  WMSXWGVPNIFBM     Ads  FireFox   M   33  3.207913e+09      0

# %%
fraud.shape
# Out:
# (120000, 11)

# %% [markdown]
# ## Stocks
#
# Prices of 10 stocks over time

# %%
stocks = pd.read_csv('../data/stocks.csv', index_col='date', parse_dates=['date'])
stocks
# Out:
#               MSFT    AAPL    SLB     AMZN    TSLA    XOM     WMT      T  \
# date
# 1999-10-25   29.84    2.32  17.02    82.75     NaN  21.45   38.99  16.78
# 1999-10-26   29.82    2.34  16.65    81.25     NaN  20.89   37.11  17.28
# 1999-10-27   29.33    2.38  16.52    75.94     NaN  20.80   36.94  18.27
# 1999-10-28   29.01    2.43  16.59    71.00     NaN  21.19   38.85  19.79
# 1999-10-29   29.88    2.50  17.21    70.62     NaN  21.47   39.25  20.00
# ...            ...     ...    ...      ...     ...    ...     ...    ...
# 2019-10-18  137.41  236.41  32.31  1757.51  256.95  67.61  119.14  38.47
# 2019-10-21  138.43  240.51  33.59  1785.66  253.50  68.74  119.74  38.23
# 2019-10-22  136.37  239.96  34.82  1765.73  255.58  69.09  119.58  38.17
# 2019-10-23  137.24  243.18  35.33  1762.17  254.68  69.75  119.35  37.74
# 2019-10-24  139.81  242.46  34.30  1777.40  298.19  69.07  119.12  37.04
#
#                 FB       V
# date
# 1999-10-25     NaN     NaN
# ...

# %% [markdown]
# ## UK Mortality Statistics
#
# All cause mortality in the UK in 2021 broken down by age and vaccination status

# %%
mort = pd.read_csv('../data/mortality.csv', parse_dates=['week'])
mort.head()
# Out:
#         week        status    age  deaths         pop  percent_of_age_group  \
# 0 2021-01-08  Unvaccinated  10-59   359.0  26822400.0                  98.1
# 1 2021-01-08  Unvaccinated  60-69   517.0   5138033.0                  98.1
# 2 2021-01-08  Unvaccinated  70-79  1132.0   4153114.0                  97.3
# 3 2021-01-08  Unvaccinated    80+  2787.0   1686889.0                  67.0
# 4 2021-01-15  Unvaccinated  10-59   398.0  26382353.0                  96.5
#
#    mortality_rate_per_100k
# 0                      1.3
# 1                     10.1
# 2                     27.3
# 3                    165.2
# 4                      1.5

# %%
mort.shape
# Out:
# (608, 7)
